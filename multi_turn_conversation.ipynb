# %%
from langgraph.graph import StateGraph, START, END, add_messages
from langgraph.types import Command, interrupt
from typing import TypedDict, Annotated, List
from langgraph.checkpoint.memory import MemorySaver
from langchain_groq import ChatGroq
from langchain_core.messages import HumanMessage, SystemMessage, AIMessage
import uuid

llm = ChatGroq(model="llama-3.1-8b-instant")

class State(TypedDict): 
    linkedin_topic: str
    generated_post: Annotated[List[str], add_messages]
    human_feedback: Annotated[List[str], add_messages]

def model(state: State): 
    """ Here, we're using the LLM to generate a LinkedIn post with human feedback incorporated """

    print("[model] Generating content")
    linkedin_topic = state["linkedin_topic"]
    feedback = state["human_feedback"] if "human_feedback" in state else ["No Feedback yet"]


    # Here, we define the prompt 

    prompt = f"""

        LinkedIn Topic: {linkedin_topic}
        Human Feedback: {feedback[-1] if feedback else "No feedback yet"}

        Generate a structured and well-written LinkedIn post based on the given topic.

        Consider previous human feedback to refine the reponse. 
    """

    response = llm.invoke([
        SystemMessage(content="You are an expert LinkedIn content writer"), 
        HumanMessage(content=prompt)
    ])

    geneated_linkedin_post = response.content

    print(f"[model_node] Generated post:\n{geneated_linkedin_post}\n")

    return {
       "generated_post": [AIMessage(content=geneated_linkedin_post)] , 
       "human_feedback": feedback
    }

def human_node(state: State): 
    """Human Intervention node - loops back to model unless input is done"""

    print("\n [human_node] awaiting human feedback...")

    generated_post = state["generated_post"]

    # Interrupt to get user feedback

    user_feedback = interrupt(
        {
            "generated_post": generated_post, 
            "message": "Provide feedback or type 'done' to finish"
        }
    )

    print(f"[human_node] Received human feedback: {user_feedback}")

    # If user types "done", transition to END node
    if user_feedback.lower() == "done": 
        return Command(update={"human_feedback": state["human_feedback"] + ["Finalised"]}, goto="end_node")

    # Otherwise, update feedback and return to model for re-generation
    return Command(update={"human_feedback": state["human_feedback"] + [user_feedback]}, goto="model")


def end_node(state: State): 
    """ Final node """
    print("\n[end_node] Process finished")
    print("Final Generated Post:", state["generated_post"][-1])
    print("Final Human Feedback", state["human_feedback"])
    return {"generated_post": state["generated_post"], "human_feedback": state["human_feedback"]}


# Buiding the Graph

graph = StateGraph(State)
graph.add_node("model", model)
graph.add_node("human_node", human_node)
graph.add_node("end_node", end_node)

graph.set_entry_point("model")

# Define the flow

graph.add_edge(START, "model")
graph.add_edge("model", "human_node")

graph.set_finish_point("end_node")

# Enable Interrupt mechanism
checkpointer = MemorySaver()
app = graph.compile(checkpointer=checkpointer)

thread_config = {"configurable": {
    "thread_id": uuid.uuid4()
}}

linkedin_topic = input("Enter your LinkedIn topic: ")
initial_state = {
    "linkedin_topic": linkedin_topic, 
    "generated_post": [], 
    "human_feedback": []
}


for chunk in app.stream(initial_state, config=thread_config):
    print(f"[main] Received chunk: {chunk}")
    print("*"*50)
    for node_id, value in chunk.items():
        #  If we reach an interrupt, continuously ask for human feedback

        if(node_id == "__interrupt__"):
            while True: 
                user_feedback = input("Provide feedback (or type 'done' when finished): ")

                # Resume the graph execution with the user's feedback
                app.invoke(Command(resume=user_feedback), config=thread_config)

                # Exit loop if user says done
                if user_feedback.lower() == "done":
                    break
# Out:
# [model] Generating content
# [model_node] Generated post:
# **Breaking Down the Hype Around AI: Separating Fact from Fiction**
#
# As AI continues to revolutionize industries and transform the way we live and work, it's essential to separate fact from fiction and cut through the hype. With so much noise being generated around AI, it's becoming increasingly challenging to distinguish between real-world applications and overhyped promises.
#
# **What's Driving the Hype?**
#
# 1. **Media Coverage**: The media loves a good story, and AI is no exception. Sensational headlines and clickbait articles often create a distorted view of AI's capabilities.
# 2. **Industry Promises**: Companies and startups are eager to showcase their AI-powered solutions, which can lead to exaggerated claims and unrealistic expectations.
# 3. **Investment and Funding**: The AI landscape has attracted significant investment and funding, fueling the hype and creating a sense of urgency around AI adoption.
#
# **What's Real and What's Not?**
#
# While AI has made tremendous progress in recent years, it's essential to temper our expectations and focus on the tangible benefits. Here are some areas where AI is delivering real results:
#
# 1. **Automation**: AI is streamlining repetitive tasks, freeing up human resources for more strategic and creative work.
# 2. **Predictive Maintenance**: AI-powered predictive maintenance is reducing downtime and increasing efficiency in industries like manufacturing and healthcare.
# 3. **Personalization**: AI-driven personalization is enhancing customer experiences and driving business growth.
#
# **The Road Ahead**
#
# As we navigate the hype around AI, it's crucial to focus on the following:
#
# 1. **Critical Thinking**: Approach AI-related claims with a critical eye, evaluating the evidence and potential outcomes.
# 2. **Collaboration**: Foster collaboration between humans and AI, leveraging each other's strengths to drive innovation and growth.
# 3. **Ethics and Responsibility**: Ensure that AI is developed and deployed with ethics and responsibility in mind, prioritizing human values and well-being.
#
# **What's Your Take?**
#
# As we continue to explore the possibilities and challenges of AI, I'd love to hear from you. Share your thoughts on the hype around AI and how you're navigating the landscape.
#
# Let's cut through the noise and have a constructive conversation about the future of AI.
#
# **Comment below** and let's get the conversation started!
#
# **Like and Share** if you found this post thought-provoking and informative!
#
# **Follow me** for more insights and analysis on the latest trends and innovations in AI and beyond!
#
#
#  [human_node] awaiting human feedback...
#
#  [human_node] awaiting human feedback...
# [human_node] Received human feedback: make it short and concise
# [model] Generating content
# [model_node] Generated post:
# **The Hype of AI: Separating Fact from Fiction**
#
# As AI continues to make headlines, it's easy to get caught up in the hype. But what does the future of AI really hold? In this post, I'll break down the facts from the fiction, and share my thoughts on what you need to know.
#
# **The Facts:**
#
# 1. **AI is changing industries**: From healthcare to finance, AI is driving innovation and improving efficiency.
# 2. **Job displacement is a reality**: While AI creates new jobs, it also automates many existing ones.
# 3. **Bias is a major concern**: AI systems can perpetuate existing biases if not designed with fairness in mind.
#
# **The Fiction:**
#
# 1. **AI will replace humans**: While AI can perform many tasks, humans will always be needed for creativity, empathy, and complex decision-making.
# 2. **AI is a silver bullet**: No technology can solve all our problems, and AI is no exception.
# 3. **AI is a threat to humanity**: The benefits of AI far outweigh the risks when designed and used responsibly.
#
# **The Future:**
#
# As AI continues to evolve, it's essential to focus on responsible development and deployment. By prioritizing transparency, fairness, and human-centered design, we can unlock the full potential of AI and create a brighter future for all.
#
# **What do you think? Share your thoughts on the hype of AI in the comments below!**
#
# #AI #FutureOfWork #Innovation #ResponsibleAI
#
#
#  [human_node] awaiting human feedback...
#
#  [human_node] awaiting human feedback...
# [human_node] Received human feedback: done
#
# [end_node] Process finished
# Final Generated Post: content="**The Hype of AI: Separating Fact from Fiction**\n\nAs AI continues to make headlines, it's easy to get caught up in the hype. But what does the future of AI really hold? In this post, I'll break down the facts from the fiction, and share my thoughts on what you need to know.\n\n**The Facts:**\n\n1. **AI is changing industries**: From healthcare to finance, AI is driving innovation and improving efficiency.\n2. **Job displacement is a reality**: While AI creates new jobs, it also automates many existing ones.\n3. **Bias is a major concern**: AI systems can perpetuate existing biases if not designed with fairness in mind.\n\n**The Fiction:**\n\n1. **AI will replace humans**: While AI can perform many tasks, humans will always be needed for creativity, empathy, and complex decision-making.\n2. **AI is a silver bullet**: No technology can solve all our problems, and AI is no exception.\n3. **AI is a threat to humanity**: The benefits of AI far outweigh the risks when designed and used responsibly.\n\n**The Future:**\n\nAs AI continues to evolve, it's essential to focus on responsible development and deployment. By prioritizing transparency, fairness, and human-centered design, we can unlock the full potential of AI and create a brighter future for all.\n\n**What do you think? Share your thoughts on the hype of AI in the comments below!**\n\n#AI #FutureOfWork #Innovation #ResponsibleAI" additional_kwargs={} response_metadata={} id='6227b83c-8fbb-4a26-ba01-07d68a289e87'
# Final Human Feedback [HumanMessage(content='make it short and concise', additional_kwargs={}, response_metadata={}, id='0e3208fc-8403-441a-83b5-69621df34a56'), HumanMessage(content='Finalised', additional_kwargs={}, response_metadata={}, id='1146ea5a-1ed2-42cf-b058-f6a9db1a07b4')]

# %%
def generate_post(state: State):
    linkedin_topic = state["linkedin_topic"]
    
    user_feedback = interrupt({
            "generated_post": generated_post, 
            "message": "Provide feedback or type 'done' to finish"
        })
    prompt = f"""Generate a LinkedIn post about {linkedin_topic} incorporating the following feedback: {user_feedback}"""
    return Command(update={"key":"ValueError"})
